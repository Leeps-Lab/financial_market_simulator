# %%
# edit this cell
session_id = '3zfm4b'

# %%
# %run /home/leeps/financial_market_simulator/app/source.ipynb
# %matplotlib inline

# %%
hft_ts_plot_meta = {
    'timestamp_column_name': 'timestamp',
    'player_meta': {
        'player_id_column_name': 'account_id',
        'y_groups': [['slider_a_x', 'slider_a_y', 'slider_a_z'],
                     ['delay'],
                     ['bid', 'offer'],
                     ['staged_bid', 'staged_offer'], 
                     ['inventory'],  
                     ['net_worth'],
                     ['best_bid_except_me', 'best_offer_except_me']
                    ],    
        # edit below set of pairs to adjust Y axis limits
        # 
        'y_limits': [(0, 5.05), (0, 0.7),  (70, 120), (70, 120), (-20, 20), (-50, 80), (80, 110)],
        'y_titles': ['Sensitivities', 'Message Delay (s)', 'Bid - Offer Spread ($)', 'Staged Bid-Offer Spread ($)', 
                     'Inventory Position', 'Net Worth', 'BB - BO (exc. this player)'],
        'legend_labels': [
            ['Signed Volume', 'Inventory', 'External Feed'], 
            ['Delay'], 
            ['Bid', 'Offer'], 
            ['Staged Bid', 'Staged Offer'], 
            ['Inventory Position'],
            ['Net Worth'], 
            ['Best Bid','Best Offer'],
        ]
    },
    'market_meta': {
        'y_groups': [['best_bid', 'best_offer', 'reference_price', 'clearing_price'], 
                     ['signed_volume'],
                    ],    
        'y_limits': [(70, 110), (-50, 50), (70, 125)],
        'y_titles': ['Best Bid/Offer', 'Signed Volume', 'External Best Bid/Offer'],
        'legend_labels': [
            ['Best Bid', 'Best Offer', 'Reference Price', 'Clearing Price'], 
            ['Signed Volume'],
        ]
    }
}

# %%
data_folder_path = 'data/'

# %%
market_filename, traders_filename = get_files_by_session_id(session_id)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-dd55d96b4276> in <module>
# ----> 1 market_filename, traders_filename = get_files_by_session_id(session_id)
#
# <ipython-input-2-9480c21ab827> in get_files_by_session_id(session_id)
#      21     market_file = [f for f in session_files if 'market' in f]
#      22     agent_file = [f for f in session_files if 'agent' in f]
# ---> 23     assert len(agent_file) == len(market_file) == 1
#      24     session_files = (market_file.pop(), agent_file.pop())
#      25     print('session files: {0}'.format(session_files))
#
# AssertionError:

# %%
 hft_report(data_folder_path + market_filename, 'Market', hft_ts_plot_meta['market_meta'], figsize=(20, 16))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-142db1bcc26a> in <module>
# ----> 1 hft_report(data_folder_path + market_filename, 'Market', hft_ts_plot_meta['market_meta'], figsize=(20, 16))
#
# NameError: name 'market_filename' is not defined

# %%
hft_report(data_folder_path + traders_filename, 'Trader', hft_ts_plot_meta['player_meta'], figsize=(20, 40))
